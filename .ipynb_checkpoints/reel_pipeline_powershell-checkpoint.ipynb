# %% [markdown]
# # Reel Pipeline (PowerShell + Speechma)
# Run top-to-bottom. This notebook builds reel video, voice, captions, and branded final output.

# %% [markdown]
# ## Setup
# Load PowerShell cell magic (one-time per session).

# %%
# %load_ext powershell_magic
# Out:
# The powershell_magic extension is already loaded. To reload it, use:
#   %reload_ext powershell_magic

# %% [markdown]
# ## Step 1: Initialize Paths and Folders
# Creates reel workspace folders and shared variables used by later cells.

# %%
# %%powershell
# # ------------------------------
# # 1) Define Paths + Core Variables
# # ------------------------------
# $PROJECT_ROOT="C:\Users\saura\Documents\youtubeVideoAgent"
# $DATE=Get-Date -Format "yyyy-MM-dd"
# $HOUR=Get-Date -Format "HH"
# $TOPIC="corey-wayne"
#
# $REEL_ROOT="$PROJECT_ROOT\assets\reels\$DATE`_$HOUR`_$TOPIC"
# $FINAL_DIR="$REEL_ROOT\final"
# $CAPTIONS_DIR="$REEL_ROOT\captions"
# $VOICE_DIR="$REEL_ROOT\voice"
# $SOURCE="C:\Users\saura\Downloads\grok-folder-1"
# $AUDIO="$VOICE_DIR\corey_wayne_voice.mp3"
# $FFMPEG="$PROJECT_ROOT\tools\ffmpeg\ffmpeg-8.1.1-essentials_build\bin\ffmpeg.exe"
# $CONCAT="$SOURCE\concat.txt"
# $STITCHED_VIDEO="$FINAL_DIR\scenes_stitched.mp4"
# $VOICED_VIDEO="$FINAL_DIR\scenes_stitched_voiced.mp4"
# $WORDS="$CAPTIONS_DIR\word_timestamps.json"
# $SRT="$CAPTIONS_DIR\captions.srt"
# $ASS="$CAPTIONS_DIR\captions.ass"
# $FINAL_OUTPUT="$FINAL_DIR\final_captioned.mp4"
# $BRANDED_OUTPUT="$FINAL_DIR\final_captioned_branded.mp4"
#
# # ------------------------------
# # 2) Create Output Folders
# # ------------------------------
# New-Item -ItemType Directory -Force $FINAL_DIR | Out-Null
# New-Item -ItemType Directory -Force $CAPTIONS_DIR | Out-Null
# New-Item -ItemType Directory -Force $VOICE_DIR | Out-Null
# Write-Host "Paths initialized"
# Out:
# Paths initialized

# %% [markdown]
# ## Step 2: Enter Speechma Narration Text
# Paste text in the output textbox and click **Save Text**.

# %%
import os
from pathlib import Path
from IPython.display import display, Markdown
import ipywidgets as widgets

WORKSPACE = Path(r"C:\Users\saura\Documents\youtubeVideoAgent\assets\reels\2026-05-10_why-you-attract-emotionally-unavailable-people")
SCRIPT_DIR = WORKSPACE / "script"
VOICE_DIR = WORKSPACE / "voice"
SCRIPT_DIR.mkdir(parents=True, exist_ok=True)
VOICE_DIR.mkdir(parents=True, exist_ok=True)

SCRIPT_FROM_CELL = SCRIPT_DIR / "script_from_cell.txt"
INPUT_FROM_CELL = VOICE_DIR / "speechma_input_from_cell.txt"

title = widgets.HTML('<b>Paste your Speechma narration text</b>')
box = widgets.Textarea(
    value='',
    placeholder='Paste your speech text here...',
    layout=widgets.Layout(width='100%', height='220px')
)
save_btn = widgets.Button(description='Save Text', button_style='success', icon='save')
status = widgets.Output()

def save_text(_):
    with status:
        status.clear_output()
        text = box.value.replace('\r', '').strip()
        if not text:
            print('Speechma text is empty. Paste text first.')
            return
        SCRIPT_FROM_CELL.write_text(text + '\n', encoding='utf-8')
        INPUT_FROM_CELL.write_text(text + '\n', encoding='utf-8')
        print('Saved:')
        print(f'- {SCRIPT_FROM_CELL}')
        print(f'- {INPUT_FROM_CELL}')

save_btn.on_click(save_text)
display(title, box, save_btn, status)
# Out:
# HTML(value='<b>Paste your Speechma narration text</b>')
# Textarea(value='', layout=Layout(height='220px', width='100%'), placeholder='Paste your speech text here...')
# Button(button_style='success', description='Save Text', icon='save', style=ButtonStyle())
# Output()

# %% [markdown]
# ## Step 3: Generate Voice with Speechma API
# Uses saved text from Step 2 and produces `voice/voice_v1.mp3` in the reel workspace.

# %%
# %%powershell
#
# # Must match Step 2.4 workspace
# $WORKSPACE = "C:\Users\saura\Documents\youtubeVideoAgent\assets\reels\2026-05-10_why-you-attract-emotionally-unavailable-people"
#
# # Use current Speechma tab page id from BrowserOS (change if needed)
# $PAGE_ID = 27
#
# # Use text prepared in Step 2.4
# $SCRIPT_FROM_CELL = Join-Path $WORKSPACE 'script\script_from_cell.txt'
# $VOICE_DIR = Join-Path $WORKSPACE 'voice'
# $VOICE_TARGET = Join-Path $VOICE_DIR 'voice_v1.mp3'
#
# $payload = @{
#   workspacePath = $WORKSPACE
#   scriptPath    = $SCRIPT_FROM_CELL
#   pageId        = $PAGE_ID
#   pitch         = 0
#   speed         = 25
#   volume        = 200
# } | ConvertTo-Json -Depth 5
#
# $res = Invoke-RestMethod -Uri "http://127.0.0.1:8787/speechma/run" -Method POST -ContentType "application/json" -Body $payload
# $res
#
# # Move latest downloaded MP3 into reel voice path
# New-Item -ItemType Directory -Force -Path $VOICE_DIR | Out-Null
# $latest = Get-ChildItem "$env:USERPROFILE\Downloads" -Filter "speechma_audio_*.mp3" -File -ErrorAction SilentlyContinue |
#   Sort-Object LastWriteTime -Descending | Select-Object -First 1
#
# if ($latest) {
#   Move-Item -LiteralPath $latest.FullName -Destination $VOICE_TARGET -Force
#   Write-Host "Moved latest download to: $VOICE_TARGET"
# } elseif ($res.outputVoicePath -and (Test-Path $res.outputVoicePath)) {
#   Copy-Item -LiteralPath $res.outputVoicePath -Destination $VOICE_TARGET -Force
#   Write-Host "No fresh download found; kept API output at: $VOICE_TARGET"
# } else {
#   throw "No Speechma MP3 found in Downloads or API output path."
# }
# Out:
# ok              : True
# pageId          : 27
# scriptPath      : C:\Users\saura\Documents\youtubeVideoAgent\assets\reels\2026-05-10_why-you-attract-emotionally-unavai
#                   lable-people\script\script_from_cell.txt
# inputPath       : C:\Users\saura\Documents\youtubeVideoAgent\assets\reels\2026-05-10_why-you-attract-emotionally-unavai
#                   lable-people\voice\speechma_input_v1.txt
# outputVoicePath : C:\Users\saura\Documents\youtubeVideoAgent\assets\reels\2026-05-10_why-you-attract-emotionally-unavai
#                   lable-people\voice\voice_v1.mp3
# proofDir        : C:\Users\saura\Documents\youtubeVideoAgent\assets\reels\2026-05-10_why-you-attract-emotionally-unavai
#                   lable-people\analysis\speechma_proof_api
# downloadedFile  : C:\Users\saura\Downloads\speechma_audio_Brian Multilingual_at_7_13_27 PM_on_May_14th_2026.mp3
# durationSeconds : 2.784
# settings        : @{pitch=0; speed=25; volume=200}
# captureProof    : False
# timeouts        : @{uiReadyTimeoutMs=60000; generationTimeoutMs=180000; downloadTimeoutMs=60000; pollMs=1500}
# minMp3Bytes     : 8000
# runLogPath      : C:\Users\saura\Documents\youtubeVideoAgent\assets\reels\2026-05-10_why-you-attract-emotionally-unavai
#                   lable-people\analysis\speechma_api_logs\speechma_run_2026-05-14T13-43-11-843Z.jsonl
# matchPhraseUsed : hello
# topic           :
# sourceRoot      :
# evidencePath    :

# %% [markdown]
# ## Step 4: Build Base Video and Mux Voice
# Creates concat file, stitches scenes, then combines stitched video with generated voice.

# %%
# %%powershell
# # Build concat file in scene order
# $PROJECT_ROOT="C:\Users\saura\Documents\youtubeVideoAgent"
# $DATE=Get-Date -Format "yyyy-MM-dd"
# $HOUR=Get-Date -Format "HH"
# $TOPIC="corey-wayne"
#
# $REEL_ROOT="$PROJECT_ROOT\assets\reels\$DATE`_$HOUR`_$TOPIC"
# $FINAL_DIR="$REEL_ROOT\final"
# $CAPTIONS_DIR="$REEL_ROOT\captions"
# $VOICE_DIR="$REEL_ROOT\voice"
# $SOURCE="C:\Users\saura\Downloads\grok-folder-1"
# $AUDIO="$VOICE_DIR\corey_wayne_voice.mp3"
# $FFMPEG="$PROJECT_ROOT\tools\ffmpeg\ffmpeg-8.1.1-essentials_build\bin\ffmpeg.exe"
# $CONCAT="$SOURCE\concat.txt"
# $STITCHED_VIDEO="$FINAL_DIR\scenes_stitched.mp4"
# $VOICED_VIDEO="$FINAL_DIR\scenes_stitched_voiced.mp4"
# $WORDS="$CAPTIONS_DIR\word_timestamps.json"
# $SRT="$CAPTIONS_DIR\captions.srt"
# $ASS="$CAPTIONS_DIR\captions.ass"
# $FINAL_OUTPUT="$FINAL_DIR\final_captioned.mp4"
# $BRANDED_OUTPUT="$FINAL_DIR\final_captioned_branded.mp4"
# Get-ChildItem $SOURCE -Filter "*.mp4" |
# Sort-Object { [int](($_.BaseName -split '_')[0]) } |
# ForEach-Object { "file '$($_.FullName.Replace('\\','/'))'" } | Set-Content $CONCAT
# Write-Host "Concat file created:" $CONCAT

# %%
# %%powershell
# # Stitch all scene clips into one base video
# $PROJECT_ROOT="C:\Users\saura\Documents\youtubeVideoAgent"
# $DATE=Get-Date -Format "yyyy-MM-dd"
# $HOUR=Get-Date -Format "HH"
# $TOPIC="corey-wayne"
#
# $REEL_ROOT="$PROJECT_ROOT\assets\reels\$DATE`_$HOUR`_$TOPIC"
# $FINAL_DIR="$REEL_ROOT\final"
# $CAPTIONS_DIR="$REEL_ROOT\captions"
# $VOICE_DIR="$REEL_ROOT\voice"
# $SOURCE="C:\Users\saura\Downloads\grok-folder-1"
# $AUDIO="$VOICE_DIR\corey_wayne_voice.mp3"
# $FFMPEG="$PROJECT_ROOT\tools\ffmpeg\ffmpeg-8.1.1-essentials_build\bin\ffmpeg.exe"
# $CONCAT="$SOURCE\concat.txt"
# $STITCHED_VIDEO="$FINAL_DIR\scenes_stitched.mp4"
# $VOICED_VIDEO="$FINAL_DIR\scenes_stitched_voiced.mp4"
# $WORDS="$CAPTIONS_DIR\word_timestamps.json"
# $SRT="$CAPTIONS_DIR\captions.srt"
# $ASS="$CAPTIONS_DIR\captions.ass"
# $FINAL_OUTPUT="$FINAL_DIR\final_captioned.mp4"
# $BRANDED_OUTPUT="$FINAL_DIR\final_captioned_branded.mp4"
# & $FFMPEG -f concat -safe 0 -i $CONCAT -c copy $STITCHED_VIDEO

# %%
# %%powershell
# # Move latest downloaded MP3 into reel voice path, then mux with video
# $PROJECT_ROOT="C:\Users\saura\Documents\youtubeVideoAgent"
# $DATE=Get-Date -Format "yyyy-MM-dd"
# $HOUR=Get-Date -Format "HH"
# $TOPIC="corey-wayne"
#
# $REEL_ROOT="$PROJECT_ROOT\assets\reels\$DATE`_$HOUR`_$TOPIC"
# $FINAL_DIR="$REEL_ROOT\final"
# $CAPTIONS_DIR="$REEL_ROOT\captions"
# $VOICE_DIR="$REEL_ROOT\voice"
# $SOURCE="C:\Users\saura\Downloads\grok-folder-1"
# $AUDIO="$VOICE_DIR\corey_wayne_voice.mp3"
# $FFMPEG="$PROJECT_ROOT\tools\ffmpeg\ffmpeg-8.1.1-essentials_build\bin\ffmpeg.exe"
# $CONCAT="$SOURCE\concat.txt"
# $STITCHED_VIDEO="$FINAL_DIR\scenes_stitched.mp4"
# $VOICED_VIDEO="$FINAL_DIR\scenes_stitched_voiced.mp4"
# $WORDS="$CAPTIONS_DIR\word_timestamps.json"
# $SRT="$CAPTIONS_DIR\captions.srt"
# $ASS="$CAPTIONS_DIR\captions.ass"
# $FINAL_OUTPUT="$FINAL_DIR\final_captioned.mp4"
# $BRANDED_OUTPUT="$FINAL_DIR\final_captioned_branded.mp4"
# Move-Item (Get-ChildItem "$env:USERPROFILE\Downloads\*.mp3" | Sort-Object LastWriteTime -Descending | Select-Object -First 1).FullName $AUDIO -Force
# & $FFMPEG -i $STITCHED_VIDEO -i $AUDIO -c:v copy -c:a aac -map 0:v:0 -map 1:a:0 -shortest $VOICED_VIDEO

# %% [markdown]
# ## Step 5: Generate Captions
# Creates word timestamps, SRT, and animated ASS captions.

# %%
# %%powershell
# # Generate word-level timestamps from audio
# $PROJECT_ROOT="C:\Users\saura\Documents\youtubeVideoAgent"
# $DATE=Get-Date -Format "yyyy-MM-dd"
# $HOUR=Get-Date -Format "HH"
# $TOPIC="corey-wayne"
#
# $REEL_ROOT="$PROJECT_ROOT\assets\reels\$DATE`_$HOUR`_$TOPIC"
# $FINAL_DIR="$REEL_ROOT\final"
# $CAPTIONS_DIR="$REEL_ROOT\captions"
# $VOICE_DIR="$REEL_ROOT\voice"
# $SOURCE="C:\Users\saura\Downloads\grok-folder-1"
# $AUDIO="$VOICE_DIR\corey_wayne_voice.mp3"
# $FFMPEG="$PROJECT_ROOT\tools\ffmpeg\ffmpeg-8.1.1-essentials_build\bin\ffmpeg.exe"
# $CONCAT="$SOURCE\concat.txt"
# $STITCHED_VIDEO="$FINAL_DIR\scenes_stitched.mp4"
# $VOICED_VIDEO="$FINAL_DIR\scenes_stitched_voiced.mp4"
# $WORDS="$CAPTIONS_DIR\word_timestamps.json"
# $SRT="$CAPTIONS_DIR\captions.srt"
# $ASS="$CAPTIONS_DIR\captions.ass"
# $FINAL_OUTPUT="$FINAL_DIR\final_captioned.mp4"
# $BRANDED_OUTPUT="$FINAL_DIR\final_captioned_branded.mp4"
# cd $PROJECT_ROOT
# python scripts\extract_word_timestamps.py --audio $AUDIO --out $WORDS

# %%
# %%powershell
# # Build SRT from word timestamps
# $PROJECT_ROOT="C:\Users\saura\Documents\youtubeVideoAgent"
# $DATE=Get-Date -Format "yyyy-MM-dd"
# $HOUR=Get-Date -Format "HH"
# $TOPIC="corey-wayne"
#
# $REEL_ROOT="$PROJECT_ROOT\assets\reels\$DATE`_$HOUR`_$TOPIC"
# $FINAL_DIR="$REEL_ROOT\final"
# $CAPTIONS_DIR="$REEL_ROOT\captions"
# $VOICE_DIR="$REEL_ROOT\voice"
# $SOURCE="C:\Users\saura\Downloads\grok-folder-1"
# $AUDIO="$VOICE_DIR\corey_wayne_voice.mp3"
# $FFMPEG="$PROJECT_ROOT\tools\ffmpeg\ffmpeg-8.1.1-essentials_build\bin\ffmpeg.exe"
# $CONCAT="$SOURCE\concat.txt"
# $STITCHED_VIDEO="$FINAL_DIR\scenes_stitched.mp4"
# $VOICED_VIDEO="$FINAL_DIR\scenes_stitched_voiced.mp4"
# $WORDS="$CAPTIONS_DIR\word_timestamps.json"
# $SRT="$CAPTIONS_DIR\captions.srt"
# $ASS="$CAPTIONS_DIR\captions.ass"
# $FINAL_OUTPUT="$FINAL_DIR\final_captioned.mp4"
# $BRANDED_OUTPUT="$FINAL_DIR\final_captioned_branded.mp4"
# cd $PROJECT_ROOT
# python scripts\build_srt_from_words.py --words $WORDS --out $SRT

# %%
# %%powershell
# # Build animated ASS captions from SRT + word timestamps
# $PROJECT_ROOT="C:\Users\saura\Documents\youtubeVideoAgent"
# $DATE=Get-Date -Format "yyyy-MM-dd"
# $HOUR=Get-Date -Format "HH"
# $TOPIC="corey-wayne"
#
# $REEL_ROOT="$PROJECT_ROOT\assets\reels\$DATE`_$HOUR`_$TOPIC"
# $FINAL_DIR="$REEL_ROOT\final"
# $CAPTIONS_DIR="$REEL_ROOT\captions"
# $VOICE_DIR="$REEL_ROOT\voice"
# $SOURCE="C:\Users\saura\Downloads\grok-folder-1"
# $AUDIO="$VOICE_DIR\corey_wayne_voice.mp3"
# $FFMPEG="$PROJECT_ROOT\tools\ffmpeg\ffmpeg-8.1.1-essentials_build\bin\ffmpeg.exe"
# $CONCAT="$SOURCE\concat.txt"
# $STITCHED_VIDEO="$FINAL_DIR\scenes_stitched.mp4"
# $VOICED_VIDEO="$FINAL_DIR\scenes_stitched_voiced.mp4"
# $WORDS="$CAPTIONS_DIR\word_timestamps.json"
# $SRT="$CAPTIONS_DIR\captions.srt"
# $ASS="$CAPTIONS_DIR\captions.ass"
# $FINAL_OUTPUT="$FINAL_DIR\final_captioned.mp4"
# $BRANDED_OUTPUT="$FINAL_DIR\final_captioned_branded.mp4"
# cd $PROJECT_ROOT
# python scripts\build_wordtimed_ass.py --srt $SRT --words $WORDS --out $ASS --preset logicloom_ref

# %% [markdown]
# ## Step 6: Burn Captions and Add Branding
# Burns ASS captions onto video, adds watermark, and prints final output path.

# %%
# %%powershell
# # Burn ASS captions into the voiced video
# $PROJECT_ROOT="C:\Users\saura\Documents\youtubeVideoAgent"
# $DATE=Get-Date -Format "yyyy-MM-dd"
# $HOUR=Get-Date -Format "HH"
# $TOPIC="corey-wayne"
#
# $REEL_ROOT="$PROJECT_ROOT\assets\reels\$DATE`_$HOUR`_$TOPIC"
# $FINAL_DIR="$REEL_ROOT\final"
# $CAPTIONS_DIR="$REEL_ROOT\captions"
# $VOICE_DIR="$REEL_ROOT\voice"
# $SOURCE="C:\Users\saura\Downloads\grok-folder-1"
# $AUDIO="$VOICE_DIR\corey_wayne_voice.mp3"
# $FFMPEG="$PROJECT_ROOT\tools\ffmpeg\ffmpeg-8.1.1-essentials_build\bin\ffmpeg.exe"
# $CONCAT="$SOURCE\concat.txt"
# $STITCHED_VIDEO="$FINAL_DIR\scenes_stitched.mp4"
# $VOICED_VIDEO="$FINAL_DIR\scenes_stitched_voiced.mp4"
# $WORDS="$CAPTIONS_DIR\word_timestamps.json"
# $SRT="$CAPTIONS_DIR\captions.srt"
# $ASS="$CAPTIONS_DIR\captions.ass"
# $FINAL_OUTPUT="$FINAL_DIR\final_captioned.mp4"
# $BRANDED_OUTPUT="$FINAL_DIR\final_captioned_branded.mp4"
# $ASS_FILTER=$ASS.Replace("\","/").Replace(":","\:")
# & $FFMPEG -i $VOICED_VIDEO -vf "ass='$ASS_FILTER'" -c:a copy $FINAL_OUTPUT

# %%
# %%powershell
# # Apply branding/watermark
# $PROJECT_ROOT="C:\Users\saura\Documents\youtubeVideoAgent"
# $DATE=Get-Date -Format "yyyy-MM-dd"
# $HOUR=Get-Date -Format "HH"
# $TOPIC="corey-wayne"
#
# $REEL_ROOT="$PROJECT_ROOT\assets\reels\$DATE`_$HOUR`_$TOPIC"
# $FINAL_DIR="$REEL_ROOT\final"
# $CAPTIONS_DIR="$REEL_ROOT\captions"
# $VOICE_DIR="$REEL_ROOT\voice"
# $SOURCE="C:\Users\saura\Downloads\grok-folder-1"
# $AUDIO="$VOICE_DIR\corey_wayne_voice.mp3"
# $FFMPEG="$PROJECT_ROOT\tools\ffmpeg\ffmpeg-8.1.1-essentials_build\bin\ffmpeg.exe"
# $CONCAT="$SOURCE\concat.txt"
# $STITCHED_VIDEO="$FINAL_DIR\scenes_stitched.mp4"
# $VOICED_VIDEO="$FINAL_DIR\scenes_stitched_voiced.mp4"
# $WORDS="$CAPTIONS_DIR\word_timestamps.json"
# $SRT="$CAPTIONS_DIR\captions.srt"
# $ASS="$CAPTIONS_DIR\captions.ass"
# $FINAL_OUTPUT="$FINAL_DIR\final_captioned.mp4"
# $BRANDED_OUTPUT="$FINAL_DIR\final_captioned_branded.mp4"
# powershell -ExecutionPolicy Bypass -File "$PROJECT_ROOT\scripts\add_logicloom_watermark.ps1" `
#  -InputVideo "$FINAL_OUTPUT" `
#  -OutputVideo "$BRANDED_OUTPUT" `
#  -LogoPath "$PROJECT_ROOT\assets\branding\playbook_logo_nobg.png"

# %%
# %%powershell
# # Final output path
# $PROJECT_ROOT="C:\Users\saura\Documents\youtubeVideoAgent"
# $DATE=Get-Date -Format "yyyy-MM-dd"
# $HOUR=Get-Date -Format "HH"
# $TOPIC="corey-wayne"
#
# $REEL_ROOT="$PROJECT_ROOT\assets\reels\$DATE`_$HOUR`_$TOPIC"
# $FINAL_DIR="$REEL_ROOT\final"
# $CAPTIONS_DIR="$REEL_ROOT\captions"
# $VOICE_DIR="$REEL_ROOT\voice"
# $SOURCE="C:\Users\saura\Downloads\grok-folder-1"
# $AUDIO="$VOICE_DIR\corey_wayne_voice.mp3"
# $FFMPEG="$PROJECT_ROOT\tools\ffmpeg\ffmpeg-8.1.1-essentials_build\bin\ffmpeg.exe"
# $CONCAT="$SOURCE\concat.txt"
# $STITCHED_VIDEO="$FINAL_DIR\scenes_stitched.mp4"
# $VOICED_VIDEO="$FINAL_DIR\scenes_stitched_voiced.mp4"
# $WORDS="$CAPTIONS_DIR\word_timestamps.json"
# $SRT="$CAPTIONS_DIR\captions.srt"
# $ASS="$CAPTIONS_DIR\captions.ass"
# $FINAL_OUTPUT="$FINAL_DIR\final_captioned.mp4"
# $BRANDED_OUTPUT="$FINAL_DIR\final_captioned_branded.mp4"
# Write-Host "FINAL VIDEO CREATED SUCCESSFULLY"
# Write-Host $BRANDED_OUTPUT
